# %%
import sys
import os

# Go up one directory from where the notebook is
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from IPython.display import Image, display

# %%
from src.orcherstration_recommender.graph import build_graph
graph = build_graph()
# Show
display(Image(graph.get_graph(xray=True).draw_mermaid_png()))
# Out:
# c:\Users\anoureldin\Desktop\TSP\nl-to-orchestration-recommender\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
### code for yassine 

from src.orcherstration_recommender.graph import graph

# Sauvegarder en PNG
png_data = graph.get_graph(xray=True).draw_mermaid_png()
with open("graph.png", "wb") as f:
    f.write(png_data)

print("Graph sauvegardé dans graph.png")
