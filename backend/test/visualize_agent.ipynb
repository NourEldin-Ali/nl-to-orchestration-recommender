# %%
import sys
import os

# Go up one directory from where the notebook is
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from IPython.display import Image, display
# Out:
# Running cells with 'Python 3.12.12' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/opt/homebrew/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'

# %%
from src.orcherstration_recommender.graph import graph
# graph = RootAgent().graph
# Show
display(Image(graph.get_graph(xray=True).draw_mermaid_png()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/9c/7cz0vzxj5z7f6h82n0sy3nf80000gn/T/ipykernel_74604/1966404650.py in <cell line: 1>()
# ----> 1 from src.orcherstration_recommender.graph import graph
#       2 # graph = RootAgent().graph
#       3 # Show
#       4 display(Image(graph.get_graph(xray=True).draw_mermaid_png()))
#
# ~/Desktop/thèse CIFRE Devoteam/these_codes/IBOAR/nl-to-orchestration-recommender/backend/src/orcherstration_recommender/graph.py in <module>
#       7 from src.orcherstration_recommender.edge import after_cypher_query_execution, after_intent_graph_update
#       8
# ----> 9 from src.orcherstration_recommender.nodes.db_schema_discovery import db_schema_discovery_node
#      10 from src.orcherstration_recommender.nodes.db_vocabulary_construction import db_vocabulary_node
#      11 from src.orcherstration_recommender.nodes.layer_extraction import layer_extraction_node
#
# ~/Desktop/thèse CIFRE Devoteam/these_codes/IBOAR/nl-to-orchestration-recommender/backend/src/orcherstration_recommender/nodes/db_schema_discovery.py in <module>
#       1 from src.orcherstration_recommender.state import State
# ----> 2 from src.config.neo4j_config import Neo4jConnector
#       3
#       4
#       5 def db_schema_discovery_node(state: State) -> State:
#
# ~/Desktop/thèse CIFRE Devoteam/these_codes/IBOAR/nl-to-orchestration-recommender/backend/src/config/neo4j_config.py in <module>
#       5
#       6
# ----> 7 class Neo4jConnector:
#       8     """
#       9     Connector for Neo4j settings and driver creation.
#
# ~/Desktop/thèse CIFRE Devoteam/these_codes/IBOAR/nl-to-orchestration-recommender/backend/src/config/neo4j_config.py in Neo4jConnector()
#      19     def __init__(
#      20         self,
# ---> 21         uri: str | None = None,
#      22         username: str | None = None,
#      23         password: str | None = None,
#
# TypeError: unsupported operand type(s) for |: 'type' and 'NoneType'

# %%
### code for yassine 

from src.orcherstration_recommender.graph import graph

# Sauvegarder en PNG
png_data = graph.get_graph(xray=True).draw_mermaid_png()
with open("graph.png", "wb") as f:
    f.write(png_data)

print("Graph sauvegardé dans graph.png")
